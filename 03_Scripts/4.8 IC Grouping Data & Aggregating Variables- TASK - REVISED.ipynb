# %% [markdown]
# # 4.8 TASK - REVISED

# %% [markdown]
# #### Importing Libraries and Data

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\ophab\Desktop\JESSICA\Careerfoundry JEJE\Data Immersion\09-2025 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_new_variables_REVISED.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 22)

# %% [markdown]
# ### Grouping Data with Panda

# %% [markdown]
# #### Aggregating Data with agg()

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #### Performing Multiple Aggregations

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %% [markdown]
# #### Aggregating Data with transform()

# %% [markdown]
# ##### .loc criteria:
# If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
#
# If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
#
# If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
ords_prods_merge.loc[ords_prods_merge['order_number'] > 40, 'loyalty_flag'] = 'Loyal Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['order_number']> 10) & (ords_prods_merge['order_number']<= 40), 'loyalty_flag'] = 'Regular Customer'

# %%
ords_prods_merge.loc[ords_prods_merge['order_number'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\ophab\AppData\Local\Temp\ipykernel_29976\1681540670.py:1: FutureWarning: The provided callable <function max at 0x0000017F397F6CA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# 5              1   2398795        1    prior             2
# 6              1   2398795        1    prior             2
# 7              1   2398795        1    prior             2
# 8              1   2398795        1    prior             2
# 9              1   2398795        1    prior             2
# 10             1   2398795        1    prior             2
# 11             2    473747        1    prior             3
# 12             2    473747        1    prior             3
# 13             2    473747        1    prior             3
# 14             2    473747        1    prior             3
#
# ...

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# New Customer        15785728
# Regular Customer    13212690
# Loyal Customer       3406441
# Name: count, dtype: int64

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id  loyalty_flag  order_number
# 0         1  New Customer             1
# 1         1  New Customer             1
# 2         1  New Customer             1
# 3         1  New Customer             1
# 4         1  New Customer             1
# 5         1  New Customer             2
# 6         1  New Customer             2
# 7         1  New Customer             2
# 8         1  New Customer             2
# 9         1  New Customer             2
# 10        1  New Customer             2
# 11        1  New Customer             3
# 12        1  New Customer             3
# 13        1  New Customer             3
# 14        1  New Customer             3
# 15        1  New Customer             3
# 16        1  New Customer             4
# 17        1  New Customer             4
# 18        1  New Customer             4
# 19        1  New Customer             4
# 20        1  New Customer             4
# 21        1  New Customer             5
# ...

# %% [markdown]
# #### Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# In this case, I applied the transformation to the entire dataframe rather than to a subset. Because I did not create or analyze a subset version, I have no direct basis for comparison between the two. Therefore, I cannot evaluate how the results might differ, as my analysis only reflects the complete dataset.

# %% [markdown]
# #### The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.¶

# %%
ords_prods_merge.groupby('loyalty_flag')['prices'].agg(['mean', 'median', 'min', 'max', 'std', 'count'])
# Out:
#                       mean  median  min   max       std     count
# loyalty_flag
# Loyal Customer    7.775537     7.4  1.0  25.0  4.189307   3406018
# New Customer      7.794679     7.4  1.0  25.0  4.255559  15782942
# Regular Customer  7.790576     7.4  1.0  25.0  4.238798  13210772

# %% [markdown]
# #### In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# #### If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# #### If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# #### If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”¶

# %%
median_days = ords_prods_merge.groupby('user_id')['days_since_prior_order'].transform('median')

# %%
ords_prods_merge.loc[median_days > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(median_days > 10) & (median_days <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[median_days <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'days_since_prior_order', 'order_frequency_flag']].tail(10)
# Out:
#           user_id      loyalty_flag  days_since_prior_order  \
# 32404849   206209  Regular Customer                    18.0
# 32404850   206209  Regular Customer                     7.0
# 32404851   206209  Regular Customer                     7.0
# 32404852   206209  Regular Customer                     7.0
# 32404853   206209  Regular Customer                     7.0
# 32404854   206209  Regular Customer                     7.0
# 32404855   206209  Regular Customer                     7.0
# 32404856   206209  Regular Customer                     7.0
# 32404857   206209  Regular Customer                     7.0
# 32404858   206209  Regular Customer                     7.0
#
#            order_frequency_flag
# 32404849  Non-frequent customer
# 32404850  Non-frequent customer
# 32404851  Non-frequent customer
# 32404852  Non-frequent customer
# 32404853  Non-frequent customer
# 32404854  Non-frequent customer
# 32404855  Non-frequent customer
# 32404856  Non-frequent customer
# ...

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_frequency_flag']].head(10)
# Out:
#    user_id  loyalty_flag   order_frequency_flag
# 0        1  New Customer  Non-frequent customer
# 1        1  New Customer  Non-frequent customer
# 2        1  New Customer  Non-frequent customer
# 3        1  New Customer  Non-frequent customer
# 4        1  New Customer  Non-frequent customer
# 5        1  New Customer  Non-frequent customer
# 6        1  New Customer  Non-frequent customer
# 7        1  New Customer  Non-frequent customer
# 8        1  New Customer  Non-frequent customer
# 9        1  New Customer  Non-frequent customer

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             0   2539329        1    prior             1                   2
# 2             0   2539329        1    prior             1                   2
# 3             0   2539329        1    prior             1                   2
# 4             0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_grouping_REVISED.pkl'))
